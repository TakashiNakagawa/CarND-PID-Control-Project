# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.genfromtxt("./build/Debug/dump_p0.txt", delimiter=",")

# %%
plt.scatter(data[:,1], data[:,0])
plt.xlabel(" p prameter")
plt.ylabel("cte*cte / count")
plt.show()

# %%
print(data[:,1][np.argmin(data[:,0])])
# Out:
# 0.125265

# %%
data2 = np.genfromtxt("./build/Debug/dump_dparam_1.txt", delimiter=",")
plt.scatter(data2[:,3], data2[:,0])
plt.xlabel(" D prameter")
plt.ylabel("cte*cte / count")
plt.show()
print(data2[:,3][np.argmin(data2[:,0])])
# Out:
# 9.22968
